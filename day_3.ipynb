# %%
x='data'
x.split('a')
# Out:
# ['d', 't', '']

# %%
x='data science'

# %%
x.count('a')
# Out:
# 2

# %%
len(x)
# Out:
# 12

# %%
x=x.replace('science','engineering')

# %%
x
# Out:
# 'data engineering'

# %%
x.index('a')
# Out:
# 1

# %%
x.index('a',1)
# Out:
# 1

# %%
x.index('a',2)
# Out:
# 3

# %%
x.count('a',2)
# Out:
# 1

# %%
x[:]
# Out:
# 'data engineering'

# %%
x[5:]
# Out:
# 'engineering'

# %%
x[0:2].upper()
# Out:
# 'DA'

# %%
x='data SCIENce'

# %%
x.split()[1].swapcase()
# Out:
# 'scienCE'

# %%
x[5:].swapcase()
# Out:
# 'scienCE'

# %%
x='data science'

# %%
x.expandtabs()
# Out:
# 'data science'

# %%
x='data\tscience'

# %%
x.expandtabs()
# Out:
# 'data    science'

# %%
x.expandtabs(100)
# Out:
# 'data                                                                                                science'

# %%
x='data\nscience'

# %%
x.expandtabs()
# Out:
# 'data\nscience'

# %%
x=' '

# %%
x.isspace()
# Out:
# True

# %%
x='machine learning'

# %%
x.find('e')
# Out:
# 6

# %%
x.find('e',7)
# Out:
# 9

# %%
x.find('e',7,9)
# Out:
# -1

# %%
x.index('e',7)
# Out:
# 9

# %%
x.index('e',7,9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x.index('e',7,9)
#
# ValueError: substring not found

# %%
x='data'

# %%
x.center(9)
# Out:
# '   data  '

# %%
x.center(9,'*')
# Out:
# '***data**'

# %%
x.zfill(10)
# Out:
# '000000data'

# %%
x='  data   '

# %%
x.strip()
# Out:
# 'data'

# %%
x.lstrip()
# Out:
# 'data   '

# %%
x.rstrip()
# Out:
# '  data'

# %%
x='data\nscience'

# %%
x
# Out:
# 'data\nscience'

# %%
x='data'

# %%
x.ljust(10)
# Out:
# 'data      '

# %%
x.rjust(10,'*')
# Out:
# '******data'
