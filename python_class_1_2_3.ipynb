# %%
ipynb: interative python notebook
.py: python
pwd: present working directory

# %%
x: delete a cell
a: create a cell above
b: create a cell below
ctrl+enter: execution
shift+enter: execution and create a new cell

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
variables
datatypes
operatorsb

# %%
name='data engineering'
duration=4
print(name)
# Out:
# data engineering

# %%
print(name)
# Out:
# data engineering

# %%
name
duration
# Out:
# 4

# %%
_name='data science'

# %%
_name
# Out:
# 'data science'

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## hai

# %%
age=10.7+3j

# %%
type(age)
# Out:
# complex

# %%
type('science')
# Out:
# str

# %%
name='koresh'
salary=200000
exp=4.8
randomnumbers=3+2j
print(salary,type(salary))
print(name,type(name))
print(exp,type(exp))
print(randomnumbers,type(randomnumbers))
# Out:
# 200000 <class 'int'>
# koresh <class 'str'>
# 4.8 <class 'float'>
# (3+2j) <class 'complex'>

# %%
x='koresh'
print(x[2:5])
# Out:
# res

# %%
print(x[:])
# Out:
# koresh

# %%
x[::]
# Out:
# 'koresh'

# %%
print(x[::])
# Out:
# koresh

# %%
x[::2]
# Out:
# 'krs'

# %%
x[::-1]
# Out:
# 'hserok'

# %%
x[::-2]
# Out:
# 'heo'

# %%
x
# Out:
# 'koresh'

# %%
x[-5:-1]
# Out:
# 'ores'

# %%
x[-5:-1:1]
# Out:
# 'ores'

# %%
x[-5:-1:-1]
# Out:
# ''

# %%
s='data science'

# %%
s.lower()
# Out:
# 'data science'

# %%
s.upper()
# Out:
# 'DATA SCIENCE'

# %%
len(s)
# Out:
# 12

# %%
s.title()
# Out:
# 'Data Science'

# %%
s.capitalize()
# Out:
# 'Data science'

# %%
s.swapcase()
# Out:
# 'DATA SCIENCE'

# %%
string='data science'
print(string.upper())
print(string.lower())
print(string.isupper())
print(string.islower())
print(string.capitalize())
print(string.title())
print(string.swapcase())
# Out:
# DATA SCIENCE
# data science
# False
# True
# Data science
# Data Science
# DATA SCIENCE

# %%
s='    data    '

# %%
s.strip()
# Out:
# 'data'

# %%
s.lstrip()
# Out:
# 'data    '

# %%
s.rstrip()
# Out:
# '    data'

# %%
string.replace('a','xyz')
# Out:
# 'dxyztxyz science'

# %%
string.count('a')
# Out:
# 2

# %%
string.count('a',1,4)
# Out:
# 2

# %%
string.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 string.index('x')
#
# ValueError: substring not found

# %%
string.find('x')
# Out:
# -1

# %%
string.endswith('e')
# Out:
# True

# %%
string.startswith('D')
# Out:
# False

# %%
string.isnumeric()
# Out:
# False

# %%
string.isalpha()
# Out:
# False

# %%
string.isalnum()
# Out:
# False

# %%
string.isdigit()
# Out:
# False

# %%
a='datascience'
a.isalpha()
# Out:
# True

# %%
b=8888
b.isnumeric()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 b=8888
# ----> 2 b.isnumeric()
#       3 b.isdigit()
#
# AttributeError: 'int' object has no attribute 'isnumeric'

# %%
b.isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 b.isdigit()
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
c='9999'

# %%
c.isnumeric()
# Out:
# True

# %%
c.isdigit()
# Out:
# True

# %%
string[0:4].isupper()
# Out:
# False

# %%
string[-3:-1].islower()
# Out:
# True

# %%
string[-3:-1].swapcase()
# Out:
# 'NC'

# %%
string[0:3].title()
# Out:
# 'Dat'

# %%
string.zfill(20)
# Out:
# '00000000data science'

# %%
string.center(20,'*')
# Out:
# '****data science****'

# %%
string.split()
# Out:
# ['data', 'science']

# %%
string.split('a')
# Out:
# ['d', 't', ' science']

# %%
'data'+'science'
# Out:
# 'datascience'

# %%
'data'*5
# Out:
# 'datadatadatadatadata'

# %%
x='Data Science'

# %%
y='data engineering'

# %%
x.split()[0].upper()+' '+y.split()[1].capitalize()
# Out:
# 'DATA Engineering'

# %%
x[0:4].upper()+' '+y[5:].capitalize()
# Out:
# 'DATA Engineering'

# %% [markdown]
# ##  List

# %%
x=[]

# %%
type(x)
# Out:
# list

# %%
x=[1,2,3,4,5]

# %%
x.append(10)

# %%
x
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
x.insert(2,33)

# %%
x
# Out:
# [1, 2, 33, 3, 4, 5, 10]

# %%
x.pop(2)
# Out:
# 33

# %%
x
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
x.pop()
# Out:
# 10

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
del x

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
l=[1,2,3,4,5,2,4,2,3,2,2]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 2, 4, 2, 3, 2, 2]

# %%
l.reverse()

# %%
l
# Out:
# [2, 2, 3, 2, 4, 2, 5, 4, 3, 2, 1]

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 2, 2, 2, 2, 3, 3, 4, 4, 5]

# %%
l.count(2)
# Out:
# 5

# %%
l.index(2)
# Out:
# 1

# %%
l.index(2,3)
# Out:
# 3

# %%
l.index(2,7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 l.index(2,7)
#
# ValueError: 2 is not in list

# %%
l.remove(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 l.remove(4)
#
# ValueError: list.remove(x): x not in list

# %%
l
# Out:
# [1, 2, 2, 2, 2, 2, 3, 3, 5]

# %%
l=[1,2,3,4,5,2,5,6]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 2, 5, 6]

# %%
l.remove(2)

# %%
l
# Out:
# [1, 3, 4, 5, 2, 5, 6]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l.sort(reverse=True)

# %%
l
# Out:
# []

# %%
l=[1,2,5,3,1,5,6,7,1]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [7, 6, 5, 5, 3, 2, 1, 1, 1]

# %%
l=['anc','xyz','anc']

# %%
l.sort()

# %%
l
# Out:
# ['anc', 'anc', 'xyz']

# %% [markdown]
# ## shallow copy

# %%
x=[1,2,3,4,5]

# %%
y=x

# %%
y[2]=33

# %%
x
# Out:
# [1, 2, 33, 4, 5]

# %% [markdown]
# ## deep copy

# %%
x=[1,2,3,4,5]

# %%
y=x.copy()

# %%
y[2]=33

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [1, 2, 33, 4, 5]
