# %% [markdown]
# ## Tupple

# %%
# immutable
# static
# faster than list
# global data

# %%
x=(1,2,3,4,5)

# %%
x.count(1)
# Out:
# 1

# %%
x.index(2)
# Out:
# 1

# %% [markdown]
# ## Dictionary

# %%
# key should be immutable

# %%
d={'a':10,'b':20,'c':30}

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d.values()
# Out:
# dict_values([10, 20, 30])

# %%
d.items()
# Out:
# dict_items([('a', 10), ('b', 20), ('c', 30)])

# %%
list(d.items())
# Out:
# [('a', 10), ('b', 20), ('c', 30)]

# %%
len(d)
# Out:
# 3
